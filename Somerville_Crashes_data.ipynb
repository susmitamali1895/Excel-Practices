# %%
import pandas as pd
import numpy as np


df = pd.read_csv('Somerville Crashes data.csv')
df_NEW = df.copy()

# %%
#Standard column names(production rule)
df_NEW.columns =(
    df_NEW.columns
    .str.strip()
    .str.lower()
    .str.replace(" ","_")
)

df_NEW.columns
# Out:
# Index(['crash_number', 'date_and_time_of_crash', 'police_shift',
#        'crash_location', 'light_conditions', 'weather_conditions',
#        'road_surface', 'road_contributing_circumstances',
#        'traffic_control_device_type', 'roadway_intersection_type',
#        'trafficway_description', 'manner_of_collision', 'first_harmful_event',
#        'first_harmful_event_location', 'speed_limit', 'work_zone',
#        'count_fatal_injury', 'count_suspected_serious_injury',
#        'count_suspected_minor_injury', 'count_possible_injury',
#        'count_no_apparent_injury', 'count_unknown_injury',
#        'count_not_reported_injury', 'total_non-motorists',
#        'pedestrian_involvement_(non-motorist)',
#        'cyclist_involvement_(non-motorist)', 'other_non-motorist_involvement',
#        'hit_and_run_flag', 'latitude', 'longitude', 'ward', 'block_code'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# Crash Number                             0
# Date and Time of Crash                   0
# Police Shift                             0
# Crash Location                           0
# Light Conditions                         0
# Weather Conditions                       0
# Road Surface                             0
# Road Contributing Circumstances          0
# Traffic Control Device Type              0
# Roadway Intersection Type                0
# Trafficway Description                   0
# Manner of Collision                      0
# First Harmful Event                      0
# First Harmful Event Location             0
# Speed Limit                              0
# Work Zone                                0
# Count Fatal Injury                       0
# Count Suspected Serious Injury           0
# Count Suspected Minor Injury             0
# Count Possible Injury                    0
# Count No Apparent Injury                 0
# Count Unknown Injury                     0
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
# save cleaned dataset (Production step)
df_NEW.to_csv("Somerville Crashes_cleaned_NEW.csv",index=False)
